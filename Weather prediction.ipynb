# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('weatherAUS.csv')

# %%
data.head(10)
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
# 5  2008-12-06   Albury     14.6     29.7       0.2          NaN       NaN
# 6  2008-12-07   Albury     14.3     25.0       0.0          NaN       NaN
# 7  2008-12-08   Albury      7.7     26.7       0.0          NaN       NaN
# 8  2008-12-09   Albury      9.7     31.9       0.0          NaN       NaN
# 9  2008-12-10   Albury     13.1     30.1       1.4          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  Pressure9am  \
# 0           W           44.0          W  ...        22.0       1007.7
# ...

# %%
data.shape
# Out:
# (142193, 24)

# %%
data = data.sample(frac=0.10,random_state=1)
print(data.shape)
# Out:
# (14219, 24)

# %%
data.isnull().sum()
# Out:
# Date                0
# Location            0
# MinTemp            65
# MaxTemp            35
# Rainfall          140
# Evaporation      6079
# Sunshine         6758
# WindGustDir       947
# WindGustSpeed     941
# WindDir9am       1059
# WindDir3pm        405
# WindSpeed9am      134
# WindSpeed3pm      300
# Humidity9am       160
# Humidity3pm       381
# Pressure9am      1364
# Pressure3pm      1363
# Cloud9am         5300
# Cloud3pm         5648
# Temp9am            73
# Temp3pm           290
# RainToday         140
# RISK_MM             0
# RainTomorrow        0
# dtype: int64

# %%
data=data.drop(['Date','Evaporation','Sunshine'],axis=1)

# %%
data.drop_duplicates(subset='Location')
# Out:
#                 Location  MinTemp  MaxTemp  Rainfall WindGustDir  \
# 64882   MelbourneAirport     18.0     26.9      21.4         SSE
# 96814           Adelaide     17.2     23.4       0.0           S
# 85767             Cairns     18.6     24.6       7.4         SSE
# 73206           Portland     13.6     16.8       4.2         ESE
# 123872           Walpole     16.4     19.9       0.0          SE
# 49566        Tuggeranong     14.9     18.3       0.0          NE
# 115929      PerthAirport      7.4     18.5       8.2           S
# 141027             Uluru     17.7     32.5       0.0          SE
# 23105      NorfolkIsland     21.8     25.9       3.6         ENE
# 4489       BadgerysCreek      5.8     22.5       0.2          NE
# 133871      AliceSprings     10.8     21.0       0.0         NaN
# 35683      SydneyAirport     26.1     37.7       0.0           S
# 68300            Mildura      7.0     21.8       0.0           W
# ...

# %%
data['Location']=data['Location'].map({'Albury':1,'BadgerysCreek':2,'Cobar':3,'CoffsHarbour':4,'Moree':5,'Newcastle':6,
'NorahHead':7,'NorfolkIsland':8,'Penrith':9,'Richmond':10,'Sydney':10,'SydneyAirport':11,'WaggaWagga':12,'Williamtown':13,
'Wollongong':14,'Canberra':15,'Tuggeranong':16,'MountGinini':17,
'Ballarat':18,'Bendigo':19,'Sale':20,'MelbourneAirport':21,'Melbourne':22,'Mildura':23,'Nhil':24,
'Portland':25,'Watsonia':26,'Dartmoor':27,'Brisbane':28,'Cairns':30,'GoldCoast':31,'Townsville':32,'Adelaide':33,'MountGambier':34,
'Nuriootpa':35,'Woomera':36,'Albany':37,'Witchcliffe':38,'PearceRAAF':39,'PerthAirport':40,'Perth':41,'SalmonGums':42,'Walpole':43,
'Hobart':44,'Launceston':45,'AliceSprings':46,'Darwin':47,'Katherine':48,'Uluru':49})

# %%
data['RainToday']=data['RainToday'].map({'Yes':1,'No':0})
data['RainTomorrow']=data['RainTomorrow'].map({'Yes':1,'No':0})

# %%
data['WindGustDir']=data['WindGustDir'].map({'N':1,'S':2,'E':3,'W':4,'NN':5,'NS':6,'NE':7,'NW':8,'SN':9,'SS':10,
'SE':11,'SW':12,'EN':13,'ES':14,'EE':15,'EW':16,'WN':17,'WS':18,'WE':19,'WW':20,'NNN':21,'NNS':22,'NNE':23,
'NNW':24,'NSN':25,'NSS':26,'NSE':27,'NSW':28,'NEN':29,'NES':30,'NEE':31,'NEW':32,'NWN':33,'NWS':34,'NWE':35,
'NWW':36,'SNN':37,'SNS':38,'SNE':39,'SNW':40,'SSN':41,'SSS':42,'SSE':43,'SSW':44,'SEN':45,'SES':46,'SEE':47,
'SEW':48,'SWN':49,'SWS':50,'SWE':51,'SWW':52,'ENN':53,'ENS':54,'ENE':55,'ENW':56,'ESN':57,'ESS':58,'ESE':59,
'ESW':60,'EEN':61,'EES':62,'EEE':63,'EEW':64,'EWN':65,'EWS':66,'EWE':67,'EWW':68,'WNN':69,'WNS':70,'WNE':71,'WNW':72,
'WSN':73,'WSS':74,'WSE':75,'WSW':76,'WEN':77,'WES':78,'WEE':79,'WEW':80,'WWN':81,'WWS':82,'WWE':83,'WWW':84})

# %%
data.head()
# Out:
#         Location  MinTemp  MaxTemp  Rainfall  WindGustDir  WindGustSpeed  \
# 64882         21     18.0     26.9      21.4         43.0           41.0
# 96814         33     17.2     23.4       0.0          2.0           41.0
# 85767         30     18.6     24.6       7.4         43.0           54.0
# 73206         25     13.6     16.8       4.2         59.0           39.0
# 123872        43     16.4     19.9       0.0         11.0           44.0
#
#        WindDir9am WindDir3pm  WindSpeed9am  WindSpeed3pm  ...  Humidity3pm  \
# 64882           W        SSE           9.0          20.0  ...         54.0
# 96814           S        WSW          13.0          19.0  ...         36.0
# 85767         SSE         SE          26.0          35.0  ...         57.0
# 73206         ESE        ESE          17.0          15.0  ...         74.0
# 123872         SE         SE          19.0          30.0  ...         70.0
#
#         Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# ...

# %%
data['WindDir9am']=data['WindDir9am'].map({'N':1,'S':2,'E':3,'W':4,'NN':5,'NS':6,'NE':7,'NW':8,'SN':9,'SS':10,
'SE':11,'SW':12,'EN':13,'ES':14,'EE':15,'EW':16,'WN':17,'WS':18,'WE':19,'WW':20,'NNN':21,'NNS':22,'NNE':23,
'NNW':24,'NSN':25,'NSS':26,'NSE':27,'NSW':28,'NEN':29,'NES':30,'NEE':31,'NEW':32,'NWN':33,'NWS':34,'NWE':35,
'NWW':36,'SNN':37,'SNS':38,'SNE':39,'SNW':40,'SSN':41,'SSS':42,'SSE':43,'SSW':44,'SEN':45,'SES':46,'SEE':47,
'SEW':48,'SWN':49,'SWS':50,'SWE':51,'SWW':52,'ENN':53,'ENS':54,'ENE':55,'ENW':56,'ESN':57,'ESS':58,'ESE':59,
'ESW':60,'EEN':61,'EES':62,'EEE':63,'EEW':64,'EWN':65,'EWS':66,'EWE':67,'EWW':68,'WNN':69,'WNS':70,'WNE':71,'WNW':72,
'WSN':73,'WSS':74,'WSE':75,'WSW':76,'WEN':77,'WES':78,'WEE':79,'WEW':80,'WWN':81,'WWS':82,'WWE':83,'WWW':84})

data['WindDir3pm']=data['WindDir3pm'].map({'N':1,'S':2,'E':3,'W':4,'NN':5,'NS':6,'NE':7,'NW':8,'SN':9,'SS':10,
'SE':11,'SW':12,'EN':13,'ES':14,'EE':15,'EW':16,'WN':17,'WS':18,'WE':19,'WW':20,'NNN':21,'NNS':22,'NNE':23,
'NNW':24,'NSN':25,'NSS':26,'NSE':27,'NSW':28,'NEN':29,'NES':30,'NEE':31,'NEW':32,'NWN':33,'NWS':34,'NWE':35,
'NWW':36,'SNN':37,'SNS':38,'SNE':39,'SNW':40,'SSN':41,'SSS':42,'SSE':43,'SSW':44,'SEN':45,'SES':46,'SEE':47,
'SEW':48,'SWN':49,'SWS':50,'SWE':51,'SWW':52,'ENN':53,'ENS':54,'ENE':55,'ENW':56,'ESN':57,'ESS':58,'ESE':59,
'ESW':60,'EEN':61,'EES':62,'EEE':63,'EEW':64,'EWN':65,'EWS':66,'EWE':67,'EWW':68,'WNN':69,'WNS':70,'WNE':71,'WNW':72,
'WSN':73,'WSS':74,'WSE':75,'WSW':76,'WEN':77,'WES':78,'WEE':79,'WEW':80,'WWN':81,'WWS':82,'WWE':83,'WWW':84})

# %%
data.head()
# Out:
#         Location  MinTemp  MaxTemp  Rainfall  WindGustDir  WindGustSpeed  \
# 64882         21     18.0     26.9      21.4         43.0           41.0
# 96814         33     17.2     23.4       0.0          2.0           41.0
# 85767         30     18.6     24.6       7.4         43.0           54.0
# 73206         25     13.6     16.8       4.2         59.0           39.0
# 123872        43     16.4     19.9       0.0         11.0           44.0
#
#         WindDir9am  WindDir3pm  WindSpeed9am  WindSpeed3pm  ...  Humidity3pm  \
# 64882          4.0        43.0           9.0          20.0  ...         54.0
# 96814          2.0        76.0          13.0          19.0  ...         36.0
# 85767         43.0        11.0          26.0          35.0  ...         57.0
# 73206         59.0        59.0          17.0          15.0  ...         74.0
# 123872        11.0        11.0          19.0          30.0  ...         70.0
#
# ...

# %%
data=data.fillna(method='ffill')

# %%
data=data.fillna(method='bfill')

# %%
cormat= data.corr()
fig=plt.figure(figsize=(12,9))
sns.heatmap(cormat,vmax=1)
plt.show()

# %%
from sklearn.metrics import classification_report,accuracy_score
from sklearn.model_selection import train_test_split

columns=data.columns.tolist()

columns=[c for c in columns if c not in ['RainTomorrow']]
target=['RainTomorrow']

X=data[columns]
Y=data[target]

X_train,X_test,Y_train,Y_test=train_test_split(X,Y,random_state=1)

# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from adspy_shared_utilities import plot_labelled_scatter

X, y = make_blobs(random_state = 10)

kmeans = KMeans(n_clusters = 3)
kmeans.fit(X)
plot_labelled_scatter(X, kmeans.labels_, ['Cluster 1', 'Cluster 2','Cluster 3'])
